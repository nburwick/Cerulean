# %%
import pandas as pd

# %%
csv = pd.read_csv("Tornado_Tracks.csv")

# %%
csv
# Out:
#        OBJECTID      om    yr  mo  dy        date      time  tz  st  stf  ...  \
# 0             1     192  1950  10   1  1950/10/01  21:00:00   3  OK   40  ...
# 1             2     193  1950  10   9  1950/10/09  02:15:00   3  NC   37  ...
# 2             3     195  1950  11  20  1950/11/20  02:20:00   3  KY   21  ...
# 3             4     196  1950  11  20  1950/11/20  04:00:00   3  KY   21  ...
# 4             5     197  1950  11  20  1950/11/20  07:30:00   3  MS   28  ...
# ...         ...     ...   ...  ..  ..         ...       ...  ..  ..  ...  ...
# 68696     68697  621922  2022   9  28  2022/09/28  13:32:00   3  FL   12  ...
# 68697     68698  621923  2022   9  30  2022/09/30  10:25:00   3  NC   37  ...
# 68698     68699  621924  2022   9  30  2022/09/30  13:22:00   3  NC   37  ...
# 68699     68700  621900  2022   9   4  2022/09/04  15:44:00   3  OH   39  ...
# 68700     68701  621901  2022   9   9  2022/09/09  23:21:00   3  SC   45  ...
#
# ...

# %%
tornadoDF = csv[["yr","st", "fat"]]
tornadoDF
# Out:
#          yr  st  fat
# 0      1950  OK    0
# 1      1950  NC    0
# 2      1950  KY    0
# 3      1950  KY    0
# 4      1950  MS    0
# ...     ...  ..  ...
# 68696  2022  FL    0
# 68697  2022  NC    0
# 68698  2022  NC    0
# 68699  2022  OH    0
# 68700  2022  SC    0
#
# [68701 rows x 3 columns]
